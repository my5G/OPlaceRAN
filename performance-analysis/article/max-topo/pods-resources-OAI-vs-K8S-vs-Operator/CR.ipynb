# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")
dataframe = pd.read_csv('PODs.csv',  delimiter=';', header=0, index_col=0)
dataframe=dataframe.astype(float)

# %%
figure, axes = plt.subplots(2, 1,figsize=(6,6))
dataframe.plot( kind='line', y='CU CPU (Millicores)', label='vCU', ax=axes[0])
dataframe.plot(kind='line', y='DU CPU (Millicores)', label='vDU', ax=axes[0])
dataframe.plot(kind='line', y='RU CPU (Millicores)', label='vRU', ax=axes[0])
dataframe.plot(kind='line', y='K8S CPU (Millicores)', label='K8S', ax=axes[0])
dataframe.plot(kind='line', y='OPERATOR CPU (Millicores)', label='OPlaceRAN', ax=axes[0])

axes[0].annotate('$\it{t0}$', xy=(0,0), xytext=(15, 3), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'), fontsize=10)
axes[0].axvline(x = 0,linestyle ="dotted", color='black', alpha=0.3)

axes[0].annotate('$\it{t1}$', xy=(90,24531), xytext=(15, 15), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'), fontsize=10)
axes[0].axvline(x = 90,linestyle ="dotted", color='black', alpha=0.3)

axes[0].annotate('$\it{t2}$', xy=(140,24531), xytext=(15, 15), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'), fontsize=10)
axes[0].axvline(x = 140,linestyle ="dotted", color='black', alpha=0.3)

axes[0].annotate('$\it{t3}$', xy=(200,5027), xytext=(15, 15), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'), fontsize=10)
axes[0].axvline(x = 200,linestyle ="dotted", color='black', alpha=0.3)

axes[0].annotate('$\it{t4}$', xy=(260,6413), xytext=(15, 15), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'), fontsize=10)
axes[0].axvline(x = 260,linestyle ="dotted", color='black', alpha=0.3)

axes[0].annotate('$\it{t5}$', xy=(315,12793), xytext=(15, 15), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'), fontsize=10)
axes[0].axvline(x = 315,linestyle ="dotted", color='black', alpha=0.3)

axes[0].annotate('$\it{t6}$', xy=(370,12973), xytext=(15, 15), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'), fontsize=10)
axes[0].axvline(x = 375,linestyle ="dotted", color='black', alpha=0.3)

axes[0].annotate('$\it{t7}$', xy=(425,12573), xytext=(15, 15), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'), fontsize=10)
axes[0].axvline(x = 425,linestyle ="dotted", color='black', alpha=0.3)

dataframe.plot(kind='line', y='CU MEMORY (MiBytes)', label='vCU', ax=axes[1])
dataframe.plot(kind='line', y='DU MEMORY (MiBytes)', label='vDU', ax=axes[1])
dataframe.plot(kind='line', y='RU MEMORY (MiBytes)', label='vRU', ax=axes[1])
dataframe.plot(kind='line', y='K8S MEMORY (MiBytes)', label='K8S', ax=axes[1])
dataframe.plot(kind='line', y='OPERATOR MEMORY (MiBytes)', label='OPlaceRAN', ax=axes[1])

axes[1].annotate('$\it{t0}$', xy=(0,94), xytext=(15, 5), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'), fontsize=10)
axes[1].axvline(x = 0,linestyle ="dotted", color='black', alpha=0.3)

axes[1].annotate('$\it{t1}$', xy=(90,11041), xytext=(15, 5), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'), fontsize=10)
axes[1].axvline(x = 90,linestyle ="dotted", color='black', alpha=0.3)

axes[1].annotate('$\it{t2}$', xy=(140,11041), xytext=(15, 15), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'), fontsize=10)
axes[1].axvline(x = 140,linestyle ="dotted", color='black', alpha=0.3)

axes[1].annotate('$\it{t3}$', xy=(200,17015), xytext=(15, 15), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'), fontsize=10)
axes[1].axvline(x = 195,linestyle ="dotted", color='black', alpha=0.3)

axes[1].annotate('$\it{t4}$', xy=(260,19670), xytext=(15, 15), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'), fontsize=10)
axes[1].axvline(x = 260,linestyle ="dotted", color='black', alpha=0.3)

axes[1].annotate('$\it{t5}$', xy=(315,20480), xytext=(15, 15), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'), fontsize=10)
axes[1].axvline(x = 315,linestyle ="dotted", color='black', alpha=0.3)

axes[1].annotate('$\it{t6}$', xy=(370,20511), xytext=(15, 15), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'), fontsize=10)
axes[1].axvline(x = 370,linestyle ="dotted", color='black', alpha=0.3)

axes[1].annotate('$\it{t7}$', xy=(425,20514), xytext=(15, 15), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'), fontsize=10)
axes[1].axvline(x = 425,linestyle ="dotted", color='black', alpha=0.3)

axes[0].set_ylabel('CPU (Millicores)')
axes[1].set_ylabel('Memory (MiBytes)')
axes[0].set_title(None)
axes[1].set_title(None)
axes[0].set_xticklabels([])
axes[0].set_xlabel(None)

axes[0].legend(loc='upper center', prop={'size': 8})
axes[1].legend(loc='upper left', prop={'size': 8})


plt.savefig('out/CR_PODS.pdf', bbox_inches='tight')
plt.savefig('out/CR_PODS.png', dpi=300, bbox_inches='tight')
