# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates
from datetime import datetime
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
names = ['PlaceRAN Start',\
     'PlaceRAN Complete',\
          'Placement start',\
               'CNFs positioned',\
                    'CNFs Allocated']
times = [0, 2, 31.58, 34, 70]

# %%
# Choose some nice levels
#levels = np.tile([-0.3, 0.3, -0.2, 0.2, -0.1, 0.1],
#                 int(np.ceil(len(times)/6)))[:len(times)]

# Create figure and plot a stem plot with the date
fig, ax = plt.subplots(figsize=(8, 2),constrained_layout=True)
#ax.set(title="Operator initial operations time")

#ax.vlines(times, 0, levels)  # The vertical stems.
ax.plot(times, np.zeros_like(times), "-o",
        color="k", markerfacecolor="w")  # Baseline and markers on it.

# annotate lines
#for d, l, r in zip(times, levels, names):
#    ax.annotate(r, xy=(d, l),
#                xytext=(-0.3, np.sign(l)*0.3), textcoords="offset points",
#                horizontalalignment="center",
#                verticalalignment="bottom" if l > 0 else "top")

ax.annotate('OPlaceRAN Start', xy=(0,0), xytext=(0, 30), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'),horizontalalignment="left")
plt.axvline(x = 0,linestyle ="dotted", color='black', alpha=0.3)

ax.annotate('$\it{t0}$', xy=(0,0), xytext=(30, -30), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'),horizontalalignment="left",verticalalignment="bottom",fontsize=15)

ax.annotate('PlaceRAN Complete', xy=(2,0), xytext=(20, 15), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'))
plt.axvline(x = 2,linestyle ="dotted", color='black', alpha=0.3)

ax.annotate('Placement Start', xy=(31.58,0), xytext=(0, 30), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'),horizontalalignment="right")
plt.axvline(x = 31.58,linestyle ="dotted", color='black', alpha=0.3)

ax.annotate('CNFs Positioned', xy=(34,0), xytext=(0, 30), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'),horizontalalignment="left")
plt.axvline(x = 34,linestyle ="dotted", color='black', alpha=0.3)

ax.annotate('CNFs Allocated', xy=(70,0), xytext=(0, 30), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'),horizontalalignment="right")
plt.axvline(x = 70,linestyle ="dotted", color='black', alpha=0.3)

ax.annotate('$\it{t1}$', xy=(70,0), xytext=(-30, -30), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'),horizontalalignment="right",verticalalignment="bottom",fontsize=15)


# remove y axis and spines
ax.yaxis.set_visible(False)
plt.xlabel("Time(s)")
#ax.margins(y=0.1)
plt.savefig('out/operator_times.pdf', bbox_inches='tight')
plt.savefig('out/operator_times.png', dpi=300, bbox_inches='tight')
