# %%
import pandas as pd 
import matplotlib.pyplot as plt
#import seaborn as sns
#sns.set_theme(style="darkgrid")
dataframe = pd.read_csv('Nodes3.csv',  delimiter=';', header=0, index_col=0)
dataframe=dataframe.astype(float)

# %%
_=dataframe.plot( kind='bar',secondary_y='MEMORY (MiBytes)')

plt.savefig('out/nodes_resources_2y.pdf', bbox_inches='tight')
plt.savefig('out/nodes_resources_2y.png', dpi=300, bbox_inches='tight')
