# %%
import pandas as pd 
import matplotlib.pyplot as plt
import os

#os.chdir('performance-analysis/graphics/cluster_resources_time/')
dataframe = pd.read_csv('Nodes.csv',  delimiter=';', header=0, index_col=0)
dataframe=dataframe.astype(float)
print(dataframe)
# Out:
#            Soma de CPU (m)  Média de CPU (m)  DesvPad de CPU (m)  \
# Tempo (s)
# 0                 108931.0        205.530189          274.811033
# 5                 109379.0        206.375472          270.895359
# 10                107760.0        203.320755          251.252791
# 15                107760.0        203.320755          251.252791
# 20                108461.0        204.643396          256.403553
# 25                108461.0        204.643396          256.403553
# 30                107727.0        203.258491          256.352714
# 35                110033.0        207.609434          277.254328
# 40                109130.0        205.905660          267.532148
# 45                109811.0        207.190566          292.829001
# 50                109811.0        207.190566          292.829001
# 55                137335.0        259.122641          783.468268
# 60                137335.0        259.122641          783.468268
# ...

# %%
ax = plt.gca()
dataframe.plot(kind='line', y='Soma de MEMORY (bytes)', label='Memory (bytes)',ax=ax)
dataframe.plot(kind='line', y='Soma de CPU (m)', label='CPU (millicpu)',ax=ax)
plt.xlabel("Time (s)")
#plt.ylabel("Memory (%)")
plt.legend()
plt.savefig('out/Nodes_MEM_CPU.pdf')
